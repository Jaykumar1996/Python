# %%
data = pd.read_csv('BL.csv')

def convert_title(cell):
    str2=''
    if cell[0] == '[':
        for i in range(1, len(cell)):
            if (cell[i] == '[') or ( cell[i] == ']') or (cell[i] == '.'):
                return str2
            str2 += cell[i]
            if (i == '.'):
                return str2
                
            
    for i in cell:
        if (i == '.') or (i == '[') or ( i == ']'):
            return str2
        str2 += i
       
    return str2      
            
data = pd.read_csv('BL.csv',converters = {'Title' : convert_title} )

print(data.Title)
# Out:
# ['Identifier',
#  'Edition Statement',
#  'Place of Publication',
#  'Date of Publication',
#  'Publisher',
#  'Title',
#  'Author',
#  'Contributors',
#  'Corporate Author',
#  'Corporate Contributors',
#  'Former owner',
#  'Engraver',
#  'Issuance type',
#  'Flickr URL',
#  'Shelfmarks']

# %%
maxi = data.sort_values("2",ascending= False)[:5]
print(maxi)

# %%
import pandas as pd
data = pd.read_csv('olympics.csv')

boolean = []
for x in data['2']:
    if (x == '0'):
        boolean.append(False)
    else:
        boolean.append(True)
        
is_long = pd.Series(boolean)

data[is_long].to_csv('out2.csv')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '2'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-116-c2d6989c2067> in <module>
#       1 boolean = []
# ----> 2 for x, in data['2']:
# ...

# %%
maxi = data.sort_values("2",ascending= False)[:5]
print(maxi)
# Out:
#                                        0   1    2    3    4     5   6   7  \
# 136  United States (USA) [P] [Q] [R] [Z]  26  976  757  666  2399  22  96
# 59                       India (IND) [F]  23    9    6   11    26   9   0
# 39                         Estonia (EST)  11    9    9   15    33   9   4
# 63                         Ireland (IRL)  20    9    8   12    29   6   0
# 104                        Romania (ROU)  20   88   94  119   301  20   0
#
#        8   9   10  11    12   13   14    15
# 136  102  84  282  48  1072  859  750  2681
# 59     0   0    0  32     9    6   11    26
# 39     2   1    7  20    13   11   16    40
# 63     0   0    0  26     9    8   12    29
# 104    0   1    1  40    88   94  120   302

# %%
import pandas as pd
data = pd.read_csv('olympics.csv')
is_long = (data['2'] != '0') & (data['3']!= '0') & (data['4']!= '0') &(data['7']!= '0') & (data['8']!= '0') & (data['9']!= '0')

data[is_long]
# Out:
#                                        0         1     2     3     4      5  \
# 0                                    NaN  ? Summer  01 !  02 !  03 !  Total
# 6              Australia (AUS) [AUS] [Z]        25   139   152   177    468
# 7                          Austria (AUT)        26    18    33    35     86
# 12                         Belarus (BLR)         5    12    24    39     75
# 13                         Belgium (BEL)        25    37    52    53    142
# 19                    Bulgaria (BUL) [H]        19    51    85    78    214
# 22                          Canada (CAN)        25    59    99   121    279
# 24                     China (CHN) [CHN]         9   201   146   126    473
# 28                         Croatia (CRO)         6     6     7    10     23
# 31            Czech Republic (CZE) [CZE]         5    14    15    15     44
# 32            Czechoslovakia (TCH) [TCH]        16    49    49    45    143
# ...

# %%
is_long = (data['2'] != '0') 
data[is_long]
# Out:
#                  0         1     2     3     4      5         6     7     8  \
# 0              NaN  ? Summer  01 !  02 !  03 !  Total  ? Winter  01 !  02 !
# 2    Algeria (ALG)        12     5     2     8     15         3     0     0
# 3  Argentina (ARG)        23    18    24    28     70        18     0     0
# 4    Armenia (ARM)         5     1     2     9     12         6     0     0
#
#       9     10       11    12    13    14              15
# 0  03 !  Total  ? Games  01 !  02 !  03 !  Combined total
# 2     0      0       15     5     2     8              15
# 3     0      0       41    18    24    28              70
# 4     0      0       11     1     2     9              12

# %%
data = pd.read_csv('BL.csv')

def convert_title(cell):
    str2=''
    if cell[0] == '[':
        for i in range(1, len(cell)):
            if (cell[i] == '[') or ( cell[i] == ']') or (cell[i] == '.'):
                return str2
            str2 += cell[i]
            if (i == '.'):
                return str2
                
            
    for i in cell:
        if (i == '.') or (i == '[') or ( i == ']'):
            return str2
        str2 += i
       
    return str2      
            
data = pd.read_csv('BL.csv',converters = {'Title' : convert_title} )

print(data.Title)
# Out:
# 0                                           Walter Forbes
# 1                                           All for Greed
# 2                                        Love the Avenger
# 3       Welsh Sketches, chiefly ecclesiastical, to the...
# 4           The World in which I live, and my place in it
# 5           The World in which I live, and my place in it
# 6                                               Lagonells
# 7                   The Coming of Spring, and other poems
# 8       A Warning to the inhabitants of England, and L...
# 9                                  A Satyr against Vertue
# 10      An Account of the many and great Loans, Benefa...
# 11      Erindringer som Bidrag til Norges Historie fra...
# 12                  Gli Studi storici in terra d'Otranto
# 13                                             De Aardbol
# 14                    Cronache Savonesi dal 1500 al 1570
# 15                                      See-Saw; a novel
# ...

# %%
data = pd.read_csv('BL.csv')

def convert_author(cell):
    last_name = ""
    first_name = ""
    middle_name = ""
    tracker = 0
    for i in range(len(cell)):
        if (cell[i] == ',') : 
            tracker += 1
            i +=1
            
        elif (cell[i] == '|' or cell[i] == '-'):
            break
        
        else:
            if (tracker == 0):
                last_name += cell[i]
            elif (tracker==1):
                first_name += cell[i]
            elif (tracker ==2):
                middle_name += cell[i]
            else:
                break
                
        #first_name= first_name.lower()
        last_name = last_name.lower()
       # middle_name = middle_name.lower()
    
       # first_name = first_name.capitalize()
        last_name = last_name.capitalize()
       # middle_name=middle_name.capitalize()
    
    if ( len(last_name) == 0):
        returnString = ''  
    elif ( len(first_name) == 0):
        returnString = last_name
    elif ( len(middle_name) == 0):
        returnString = last_name + ',' + first_name
    else:
        returnString = last_name + ',' + first_name + ',' + middle_name
    
    return returnString


            
data = pd.read_csv('BL.csv',converters = {'Author' : convert_author, 'Contributors' : convert_author} )

print(data.Contributors)

data.to_csv('out1.csv')
# Out:
# 0                          Forbes, Walter.
# 1       Blaze de bury, Marie Pauline Rose
# 2       Blaze de bury, Marie Pauline Rose
# 3              Appleyard, Ernest Silvanus.
# 4                      Broome, John Henry.
# 5                      Broome, John Henry.
# 6                  Ashley, Florence Emily.
# 7                             Andrews, J.
# 8                             Adams, Mary.
# 9                            Oldham, John.
# 10                          Carte, Samuel.
# 11                             Aall, J. C.
# 12                            S., L. G. D.
# 13                  Witkamp, Pieter Harme.
# 14                     Assereto, Giovanni.
# 15                 Reade, William Winwood.
# 16                        Radau, Rodolphe.
# 17                        Radau, Rodolphe.
# 18        Acosta y calbo, José Julian de.
# 19                           André, John
# 20                      Wrangham, Francis.
# 21                  Barham, Thomas Foster
# ...
