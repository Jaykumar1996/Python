# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from matplotlib import pyplot as plt2
from matplotlib import pyplot as plt3

data = pd.read_csv('Sac.csv')

condo = data[data.type == 'Condo'].sort_values( by = ['zip'])
res = data[data.type == 'Residential']
multi = data[data.type == 'Multi-Family']

def removeDuplicates(listofElements):
    uniqueList = []
    for elem in listofElements:
        if elem not in uniqueList:
            uniqueList.append(elem)           
    return uniqueList


z = condo['zip']
z = removeDuplicates(z)
z_condo = condo.groupby('zip')['price'].mean()
plt.bar(z, z_condo, align='center', alpha=1)


z = res['zip']
z = removeDuplicates(z)
z_res = res.groupby('zip')['price'].mean()
plt2.bar(z, z_res, align='center', alpha=1)


z = multi['zip']
z = removeDuplicates(z)
z_multi = multi.groupby('zip')['price'].mean()
plt3.bar(z, z_multi, align='center', alpha=1)

#plt.legend(["Condo", "Residential", "Multi-Family"])
# Out:
# <BarContainer object of 9 artists>

# %%
data = pd.read_csv('Sac.csv')

condo = data[data.type == 'Condo'].sort_values( by = ['zip'])
res = data[data.type == 'Residential']
multi = data[data.type == 'Multi-Family']

def removeDuplicates(listofElements):
    uniqueList = []
    for elem in listofElements:
        if elem not in uniqueList:
            uniqueList.append(elem)           
    return uniqueList

z = condo['city']
z = removeDuplicates(z)
z_condo = condo.groupby('city')['price'].mean()
plt.bar(z, z_condo, align='center', alpha=1)


z = res['city']
z = removeDuplicates(z)
z_res = res.groupby('city')['price'].mean()
plt.bar(z, z_res, align='center', alpha=1)


z = multi['city']
z = removeDuplicates(z)
z_multi = multi.groupby('city')['price'].mean()
plt.bar(z, z_multi, align='center', alpha=1)

plt.legend(["Condo", "Residential", "Multi-Family"])

# %%
import pandas as pd
from matplotlib import pyplot as plt

fig = plt.figure()
ax = fig.add_subplot(111)

data = pd.read_csv('Sac.csv')

condo = data[data.type == 'Condo']
y_condo = condo["price"]
x_condo = condo.zip
plt.scatter(x_condo,y_condo)

ymax = condo["price"].max()
i = condo["price"].idxmax()
xmax = condo.zip[i]

ax.annotate('condo max', xy=(xmax, ymax), xytext=(xmax, ymax+5),
            arrowprops=dict(facecolor='black', shrink=0.05),
            )

residential = data[data.type == "Residential"]
y_res = residential.price
x_res = residential.zip
plt.scatter(x_res,y_res)


ymax = residential["price"].max()
i = residential["price"].idxmax()
xmax = residential.zip[i]

ax.annotate('residential max', xy=(xmax, ymax), xytext=(xmax, ymax+5),
            arrowprops=dict(facecolor='black', shrink=0.05),
            )


multi = data[data.type == "Multi-Family"]
y_multi = multi.price
x_multi = multi.zip
plt.scatter(x_multi,y_multi)

ymax = multi["price"].max()
i = multi["price"].idxmax()
xmax = multi.zip[i]

ax.annotate('Multi-Family max', xy=(xmax, ymax), xytext=(xmax, ymax+5),
            arrowprops=dict(facecolor='black', shrink=0.05),
            )




plt.legend(["Condo", "Residential", "Multi-Family"])

plt.grid()
plt.show()

# %%
import pandas as pd
from matplotlib import pyplot as plt

data = pd.read_csv('Sac.csv')
condo = data[data.type == 'Condo'].sort_values( by = ['zip']).head()
res = data[data.type == 'Residential'].head()

pd.merge(condo,res,on='state')
# Out:
#                    street_x          city_x  zip_x state  beds_x  baths_x  \
# 0     2231 COUNTRY VILLA CT          AUBURN  95603    CA       2        2
# 1     2231 COUNTRY VILLA CT          AUBURN  95603    CA       2        2
# 2     2231 COUNTRY VILLA CT          AUBURN  95603    CA       2        2
# 3     2231 COUNTRY VILLA CT          AUBURN  95603    CA       2        2
# 4     2231 COUNTRY VILLA CT          AUBURN  95603    CA       2        2
# 5              4010 ALEX LN      CARMICHAEL  95608    CA       2        2
# 6              4010 ALEX LN      CARMICHAEL  95608    CA       2        2
